# %%
# Import Packages

from os.path import exists
import pickle
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

time_start = pd.Timestamp.now()

# %% [markdown]
# ## Obtain Election Data

# %%
# check to see if the data has been captured
# if True then move on, if False then grab data and capture information

if exists('./data/dataPickle'):
    print('Data exists in the dataPickle file')
else:
    # Setup pickle file to store scraped tables

    # create and open pickle file 
    election_scraped_file = open('./data/dataPickle', 'ab')

    # extract datat from source
    election_scrape = pd.read_html('https://alex.github.io/nyt-2020-election-scraper/all-state-changes.html')

    # add content to pickle file
    pickle.dump(election_scrape, election_scraped_file)

    # closse pickle file
    election_scraped_file.close()
    
    print('Data file not found.  Data is now stored in the dataPickle file')
# Out:
# Data exists in the dataPickle file

# %%
stored_pickle_file = open('./data/dataPickle', 'rb')
election_results = pickle.load(stored_pickle_file)

# %% [markdown]
# ## Create summary table

# %%
# extract out header information that contains total votes, electoral votes, percentages, and winner
summary_table = []

for state in election_results:
    stringState = state.columns.get_level_values(0)[0]
    d = stringState.split("  ",2)
    state_name = d[0].split("(")[0].strip()
    electoral_votes = d[0].split("(EV: ")[1].replace(")","").strip()
    s = d[1].replace(",","")
    lead_votes, lead_percent, trail_votes, trail_percent = [float(i) for i in re.findall(r'([0-9]+\.?\d)', s)]
    leader, trailer = re.findall(r'([A-Z][a-z]+)',s)
    dict = {
        'State': state_name, 
        'Electoral Votes': int(electoral_votes), 
        'Leader': leader, 
        'Leader Total Votes': lead_votes, 
        'Leader Vote Percent': lead_percent, 
        'Trailer': trailer, 
        'Trailer Total Votes': trail_votes, 
        'Trailer Vote Percent': trail_percent
    }
    summary_table.append(dict)
summary_df = pd.DataFrame(summary_table)
summary_df.head()
# Out:
#         State  Electoral Votes Leader  Leader Total Votes  \
# 0     Alabama                9  Trump           1441170.0
# 1      Alaska                3  Trump            189951.0
# 2     Arizona               11  Biden           1672143.0
# 3    Arkansas                6  Trump            760647.0
# 4  California               55  Biden          11109764.0
#
#    Leader Vote Percent Trailer  Trailer Total Votes  Trailer Vote Percent
# 0                 62.0   Biden             849624.0                  36.6
# 1                 52.8   Biden             153778.0                  42.8
# 2                 49.4   Trump            1661686.0                  49.1
# 3                 62.4   Biden             423932.0                  34.8
# 4                 63.5   Trump            6005961.0                  34.3

# %%
# Check data types for accuracy
summary_df.dtypes
# Out:
# State                    object
# Electoral Votes           int64
# Leader                   object
# Leader Total Votes      float64
# Leader Vote Percent     float64
# Trailer                  object
# Trailer Total Votes     float64
# Trailer Vote Percent    float64
# dtype: object

# %%
# Store summary table as csv
summary_df.to_csv('./data/summary.csv', index=False)

# %% [markdown]
# ## Make election results table

# %%
def extract_batch(s, index):
    string = re.findall(r'([0-9]+\.?\d)', s)
    try:
        strval = string[index]
    except:
        strval = None
        
    return strval

# %%
# election_records = pd.read_html('https://alex.github.io/nyt-2020-election-scraper/all-state-changes.html')
frames = []

for state in election_results:
    stringState = state.columns.get_level_values(0)[0]
    d = stringState.split("  ",2)
    state_name = d[0].split("(")[0].strip()
    df = state
    df.columns = df.columns.droplevel(0)
    df['State'] = state_name
    df['Leader Batch Breakdown'] = df['Batch Breakdown'].apply(lambda x: extract_batch(str(x), 0) )
    df['Trailer Batch Breakdown'] = df['Batch Breakdown'].apply(lambda x: extract_batch(str(x), 1) )
    df['Trailer Batch Trend'] = df['Batch Trend'].apply(lambda x: extract_batch(str(x), 0) )
    df['Trailer Hurdle'] = df['Hurdle'].apply(lambda x: extract_batch(str(x), 0) )
    df.drop('Unnamed: 8_level_1', axis='columns', inplace=True)
    df.drop('Batch Breakdown', axis='columns', inplace=True)
    df.drop(['Batch Trend', 'Hurdle'], axis='columns', inplace=True)
    frames.append(df)

result_df = pd.concat(frames)

# %%
# instead of using .dtypes, use .info() to see aditional information
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3406 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                3406 non-null   object
#  1   In The Lead              3406 non-null   object
#  2   Vote Margin              3406 non-null   int64
#  3   Votes Remaining (est.)   3406 non-null   object
#  4   Change                   3406 non-null   object
#  5   State                    3406 non-null   object
#  6   Leader Batch Breakdown   2886 non-null   object
#  7   Trailer Batch Breakdown  2886 non-null   object
#  8   Trailer Batch Trend      3298 non-null   object
#  9   Trailer Hurdle           3166 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 292.7+ KB

# %%
# Store batch vote records for each state
# don't include the index column
result_df.to_csv('./data/raw_records.csv', index=False)

# %% [markdown]
# ## Dataset Review

# %% [markdown]
# The data in the columns is not very helpful in its current form.  I need the geospacial-temporal data to have a highly versatile dataset.
# Since this data is mostly about batches of votes but has some faulty information, I need to calculate the vote counting trends based on the final vote tally and this batch data.  Verifying the validity of the data is necessary.
#
# The columns that I need are time, candidate, batch votes, state, district, maybe a note if any of the records were estimated or not.
#
# Here are somet things I think that should be checked:
# * Do the zero values in the 'Change' column need to be removed?  Is there anything else wrong with this data?
# * Do the 'Unknown' values in the 'Change' column need to be removed?
# * Can I estimate the 'Change' column zero and 'Unknown' values from the change in the margin votes and the percent of the leader batch votes?
# * Is the change in margin between batches smaller than the batch size?  This must be true and values that violate this are likely faulty.
#
# In the end, the batch votes need to be filtered for faulty data and the individual batch candidate votes should be calculated from the existing data.

# %%
# Create two new columns, convert 3 columns to numeric type
result_df['Margin_change_estimate']=""
result_df['Type']=""
result_df[['Margin_change_estimate','Leader Batch Breakdown', 'Trailer Batch Breakdown']]=result_df[['Margin_change_estimate', 'Leader Batch Breakdown', 'Trailer Batch Breakdown']].apply(pd.to_numeric)

# renumber index and discard current index
result_df.reset_index(drop=True, inplace=True)

# view updated column info
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3406 entries, 0 to 3405
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                3406 non-null   object
#  1   In The Lead              3406 non-null   object
#  2   Vote Margin              3406 non-null   int64
#  3   Votes Remaining (est.)   3406 non-null   object
#  4   Change                   3406 non-null   object
#  5   State                    3406 non-null   object
#  6   Leader Batch Breakdown   2886 non-null   float64
#  7   Trailer Batch Breakdown  2886 non-null   float64
#  8   Trailer Batch Trend      3298 non-null   object
#  9   Trailer Hurdle           3166 non-null   object
#  10  Margin_change_estimate   0 non-null      float64
#  11  Type                     3406 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 319.4+ KB

# %% [markdown]
# ## Zero Data Review

# %%
# Check Zero Data - is it real or is it flawed
# Note - searching for a string bc I can not convert to numeric directly until "Unknowns" are removed
result_df[result_df["Change"] == "0"]
# shows what looks like data without any percent breakdowns of the batch
# Out:
#                     Timestamp In The Lead  Vote Margin Votes Remaining (est.)  \
# 5     2020-11-11 03:23:42 UTC       Trump       590686                  13386
# 13    2020-11-04 13:28:22 UTC       Trump       618344                  93031
# 14    2020-12-02 19:04:28 UTC       Trump        36173                  31816
# 15    2020-12-02 17:18:21 UTC       Trump        36173                  31816
# 16    2020-12-02 16:33:22 UTC       Trump        36173                  31816
# ...                       ...         ...          ...                    ...
# 3358  2020-11-10 13:17:25 UTC       Trump       307807                   6992
# 3359  2020-11-09 23:16:41 UTC       Trump       307807                   6992
# 3372  2020-11-04 13:28:22 UTC       Trump       307126                   8526
# 3399  2020-11-04 17:33:32 UTC       Biden        20697                    592
# 3400  2020-11-04 13:28:22 UTC       Biden        20697                    592
#
#      Change          State  Leader Batch Breakdown  Trailer Batch Breakdown  \
# 5         0        Alabama                     NaN                      NaN
# 13        0        Alabama                     NaN                      NaN
# 14        0         Alaska                     NaN                      NaN
# 15        0         Alaska                     NaN                      NaN
# 16        0         Alaska                     NaN                      NaN
# ...     ...            ...                     ...                      ...
# 3358      0  West Virginia                     NaN                      NaN
# 3359      0  West Virginia                     NaN                      NaN
# 3372      0  West Virginia                     NaN                      NaN
# 3399      0      Wisconsin                     NaN                      NaN
# 3400      0      Wisconsin                     NaN                      NaN
#
#      Trailer Batch Trend Trailer Hurdle  Margin_change_estimate Type
# 5                   44.9         2287.6                     NaN
# 13                  None          387.0                     NaN
# 14                  49.4          109.5                     NaN
# 15                  49.4          109.5                     NaN
# 16                  49.4          109.5                     NaN
# ...                  ...            ...                     ...  ...
# 3358                34.6         2288.6                     NaN
# 3359                34.6         2288.6                     NaN
# 3372                None         1881.7                     NaN
# 3399                None         1828.6                     NaN
# 3400                None         1828.6                     NaN
#
# [364 rows x 12 columns]

# %%
# check to see if any of the percent columns have bad data (values greater than 100%)
result_df[(result_df["Change"] == "0") & ( (result_df["Leader Batch Breakdown"] >100) | (result_df["Trailer Batch Breakdown"] >100) )]
# Note: there are no records of Change data outside noral percentages
# Out:
# Empty DataFrame
# Columns: [Timestamp, In The Lead, Vote Margin, Votes Remaining (est.), Change, State, Leader Batch Breakdown, Trailer Batch Breakdown, Trailer Batch Trend, Trailer Hurdle, Margin_change_estimate, Type]
# Index: []

# %%
# check to see if the vote percents add up to 100%
result_df[(result_df["Change"] == "0") & (result_df["Leader Batch Breakdown"] + result_df["Trailer Batch Breakdown"] == 100) ]

# Note:  none of the values add up to 100 so all values can be thrown out as bad data since individual percents are not greater than 100 and they don't add up to 100
# Out:
# Empty DataFrame
# Columns: [Timestamp, In The Lead, Vote Margin, Votes Remaining (est.), Change, State, Leader Batch Breakdown, Trailer Batch Breakdown, Trailer Batch Trend, Trailer Hurdle, Margin_change_estimate, Type]
# Index: []

# %% [markdown]
# ## Unknown Data Review

# %%
# Check if Unknowns should be thrown out
unknown_df = result_df[result_df['Change']=="Unknown"]
print(f"Number of Unknowns: {len(unknown_df)}")
unknown_df.head()
# Out:
# Number of Unknowns: 113
#                    Timestamp In The Lead  Vote Margin Votes Remaining (est.)  \
# 0    2021-01-05 15:21:52 UTC       Trump       591546                      4
# 7    2020-11-06 18:40:11 UTC       Trump       596046                  26070
# 22   2020-11-25 01:59:12 UTC       Trump        36355                  34858
# 157  2020-11-16 18:16:52 UTC       Trump       338005                   7175
# 192  2020-11-09 17:17:21 UTC       Trump       338978                   9790
#
#       Change     State  Leader Batch Breakdown  Trailer Batch Breakdown  \
# 0    Unknown   Alabama                     9.1                    109.1
# 7    Unknown   Alabama                     5.9                    105.9
# 22   Unknown    Alaska                     6.8                    106.8
# 157  Unknown  Arkansas                    74.0                     26.0
# 192  Unknown  Arkansas                    48.6                     51.4
#
#     Trailer Batch Trend Trailer Hurdle  Margin_change_estimate Type
# 0                  58.5      7499241.2                     NaN
# 7                  49.1         1209.4                     NaN
# 22                 48.2          104.5                     NaN
# 157                36.0         2474.0                     NaN
# 192                29.2         1831.7                     NaN

# %%
# I can use the percents and change in vote margin to calculate the votes for each candidate.  This is not an ideal way since 
# percents are rounded and induce error.

# check if percents add to one hundred percent
result_df[ (result_df['Change']=="Unknown") & (result_df['Leader Batch Breakdown'] + result_df['Trailer Batch Breakdown'] == 100) ]
# These 97 rows can be used to calculate the Unknown value
# Out:
#                     Timestamp In The Lead  Vote Margin Votes Remaining (est.)  \
# 157   2020-11-16 18:16:52 UTC       Trump       338005                   7175
# 192   2020-11-09 17:17:21 UTC       Trump       338978                   9790
# 193   2020-11-09 16:41:11 UTC       Trump       338874                   5916
# 197   2020-11-06 19:30:23 UTC       Trump       337918                  11131
# 198   2020-11-06 19:13:48 UTC       Trump       340363                   6134
# ...                       ...         ...          ...                    ...
# 3369  2020-11-08 16:45:34 UTC       Trump       307108                   8464
# 3373  2020-12-08 01:37:07 UTC       Biden        20608                     76
# 3381  2020-11-16 19:31:33 UTC       Biden        20546                    202
# 3389  2020-11-12 01:26:41 UTC       Biden        20798                    321
# 3397  2020-11-04 18:30:33 UTC       Biden        20509                    294
#
#        Change          State  Leader Batch Breakdown  Trailer Batch Breakdown  \
# 157   Unknown       Arkansas                    74.0                     26.0
# 192   Unknown       Arkansas                    48.6                     51.4
# 193   Unknown       Arkansas                    75.7                     24.3
# 197   Unknown       Arkansas                    75.7                     24.3
# 198   Unknown       Arkansas                    48.7                     51.3
# ...       ...            ...                     ...                      ...
# 3369  Unknown  West Virginia                    65.3                     34.7
# 3373  Unknown      Wisconsin                    61.9                     38.1
# 3381  Unknown      Wisconsin                     0.0                    100.0
# 3389  Unknown      Wisconsin                     0.7                     99.3
# 3397  Unknown      Wisconsin                    68.8                     31.2
#
#      Trailer Batch Trend Trailer Hurdle  Margin_change_estimate Type
# 157                 36.0         2474.0                     NaN
# 192                 29.2         1831.7                     NaN
# 193                 33.3         2997.4                     NaN
# 197                 33.7         1612.1                     NaN
# 198                 27.3         2905.2                     NaN
# ...                  ...            ...                     ...  ...
# 3369                56.5         1895.0                     NaN
# 3373                64.4        13844.7                     NaN
# 3381                67.6         5224.5                     NaN
# 3389                35.8         3346.2                     NaN
# 3397                82.6         3598.9                     NaN
#
# [97 rows x 12 columns]

# %%
result_df[ (result_df['Change']=="Unknown") & (result_df['Leader Batch Breakdown'] + result_df['Trailer Batch Breakdown'] != 100) ]
# These 16 rows have faulty change and percent breakdowns so these batch records should be thrown out.
# Out:
#                     Timestamp In The Lead  Vote Margin Votes Remaining (est.)  \
# 0     2021-01-05 15:21:52 UTC       Trump       591546                      4
# 7     2020-11-06 18:40:11 UTC       Trump       596046                  26070
# 22    2020-11-25 01:59:12 UTC       Trump        36355                  34858
# 899   2020-11-09 21:52:34 UTC       Biden       711793                 535553
# 993   2020-11-11 14:59:03 UTC       Trump       138793                   3227
# 1629  2020-11-25 14:47:14 UTC       Biden       233039                  90020
# 1632  2020-11-25 14:10:14 UTC       Biden       232802                  94785
# 1813  2020-12-06 14:16:59 UTC       Trump       217366                  12735
# 1823  2020-11-17 02:21:52 UTC       Trump       236423                  67085
# 1878  2020-12-09 14:21:38 UTC       Trump       465722                   1422
# 2441  2020-11-09 20:27:00 UTC       Trump       470723                 157615
# 2974  2020-11-09 21:44:56 UTC       Trump       647601                  68196
# 3096  2020-11-17 20:55:57 UTC       Biden       450833                  18042
# 3097  2020-11-17 20:48:37 UTC       Biden       450788                  19687
# 3098  2020-11-17 20:40:39 UTC       Biden       450584                  22881
# 3383  2020-11-16 19:15:12 UTC       Biden        20527                    261
#
#        Change        State  Leader Batch Breakdown  Trailer Batch Breakdown  \
# 0     Unknown      Alabama                     9.1                    109.1
# 7     Unknown      Alabama                     5.9                    105.9
# 22    Unknown       Alaska                     6.8                    106.8
# 899   Unknown     Illinois                    38.3                    138.3
# 993   Unknown         Iowa                   114.3                     14.3
# 1629  Unknown    Minnesota                    37.0                    137.0
# 1632  Unknown    Minnesota                   300.0                    400.0
# 1813  Unknown  Mississippi                    52.4                    152.4
# 1823  Unknown  Mississippi                   736.4                    836.4
# 1878  Unknown     Missouri                    13.3                    113.3
# 2441  Unknown         Ohio                    46.4                    146.4
# 2974  Unknown        Texas                   123.2                     23.2
# 3096  Unknown     Virginia                    14.3                    114.3
# 3097  Unknown     Virginia                     3.7                    103.7
# 3098  Unknown     Virginia                   105.4                      5.4
# 3383  Unknown    Wisconsin                   105.9                      5.9
#
#      Trailer Batch Trend Trailer Hurdle  Margin_change_estimate Type
# 0                   58.5      7499241.2                     NaN
# 7                   49.1         1209.4                     NaN
# 22                  48.2          104.5                     NaN
# 899                 21.6          117.7                     NaN
# 993                 39.1         2244.8                     NaN
# 1629                52.7          182.5                     NaN
# 1632                52.7          175.7                     NaN
# 1813                69.3          915.9                     NaN
# 1823                54.3          228.8                     NaN
# 1878                59.6        16724.3                     NaN
# 2441                34.0          201.6                     NaN
# 2974                66.1          532.0                     NaN
# 3096                25.3         1323.5                     NaN
# 3097                24.9         1217.0                     NaN
# 3098                25.4         1053.6                     NaN
# 3383                70.2         4051.1                     NaN

# %% [markdown]
# ## Change in Margin Data Review

# %%
# For each batch added the margin of the votes can not increase/decrease more than the Change columns
# key for this is to enure we are only looking at data for each state because if the last row has an unknown then this calculation will not work

# create a copy of the data so I can change the index a bit
# I added the 'Margin_change_estimate' column in the original dataframe so the df are identical
df = result_df.copy()

# preserve the original index in the groupby (next step)
df.reset_index(inplace=True)

# first find the last rows of each state
last_row_list = list(df.groupby('State').last()['index'])
print(last_row_list)
# Out:
# [13, 39, 125, 211, 355, 428, 559, 565, 575, 624, 850, 854, 863, 933, 984, 1060, 1153, 1210, 1225, 1321, 1419, 1545, 1622, 1810, 1873, 1890, 1910, 1935, 1981, 2046, 2191, 2216, 2298, 2364, 2401, 2443, 2448, 2484, 2820, 2832, 2896, 2938, 2945, 3001, 3055, 3085, 3191, 3341, 3372, 3400, 3405]

# %%
# go through original df and create the change in margin calculation except on last rows of each state
for i in range(len(result_df)-1):
    if i not in last_row_list:
        vote_margin_now = result_df.iloc[i,2]
        vote_margin_prev = result_df.iloc[i+1, 2]
        result_df.iloc[i, 10] = abs(vote_margin_now - vote_margin_prev)

# %%
# how many NaN are in the Margin_change_estimate column - these are last row values that lack data to calculate a change value
# remove all of these values from the df
result_df[ result_df['Margin_change_estimate'].isnull() ]
# Actually, lets leave them in the df since these are the last row values
# Out:
#                     Timestamp In The Lead  Vote Margin Votes Remaining (est.)  \
# 13    2020-11-04 13:28:22 UTC       Trump       618344                  93031
# 39    2020-11-04 13:28:22 UTC       Trump        35241                 258871
# 125   2020-11-04 13:28:22 UTC       Biden       130665                 746304
# 211   2020-11-04 13:28:22 UTC       Trump       335478                  21014
# 355   2020-11-04 13:28:22 UTC       Biden      3829646                5647390
# 428   2020-11-04 13:28:22 UTC       Biden       410357                 333648
# 559   2020-11-04 13:28:22 UTC       Biden       294420                 237831
# 565   2020-11-04 13:28:22 UTC       Biden        95573                   1667
# 575   2020-11-04 13:28:22 UTC       Biden       199740                 113818
# 624   2020-11-04 13:28:22 UTC       Trump       377023                  36016
# 850   2020-11-04 13:28:22 UTC       Trump       103760                 272257
# 854   2020-11-04 13:28:22 UTC       Biden       168807                  22253
# 863   2020-11-04 13:28:22 UTC       Trump       245152                  30852
# 933   2020-11-04 13:28:22 UTC       Biden       611495                1540930
# 984   2020-11-04 13:28:22 UTC       Trump       547061                 444889
# 1060  2020-11-04 13:28:22 UTC       Trump       123374                   4318
# 1153  2020-11-04 13:28:22 UTC       Trump       176777                  81289
# 1210  2020-11-04 13:28:22 UTC       Trump       574356                  16846
# 1225  2020-11-04 13:28:22 UTC       Trump       399884                    749
# 1321  2020-11-04 13:28:22 UTC       Biden        77489                 199059
# 1419  2020-11-04 13:28:22 UTC       Biden       609267                 929248
# 1545  2020-11-04 13:28:22 UTC       Biden       865899                1220779
# 1622  2020-11-04 13:28:22 UTC       Trump        27533                 656237
# 1810  2020-11-04 13:28:22 UTC       Biden       229985                 167976
# 1873  2020-11-04 13:28:22 UTC       Trump       222426                 450974
# 1890  2020-11-04 13:28:22 UTC       Trump       468996                  18830
# 1910  2020-11-04 13:28:22 UTC       Trump        70379                  76385
# 1935  2020-11-04 13:28:22 UTC       Trump       153735                  71626
# 1981  2020-11-04 13:28:22 UTC       Biden         7647                 212461
# 2046  2020-11-04 13:28:22 UTC       Biden        49377                 199832
# 2191  2020-11-04 13:28:22 UTC       Biden       667249                1663332
# 2216  2020-11-04 13:28:22 UTC       Biden        92285                  10829
# 2298  2020-11-04 13:28:22 UTC       Biden      1254581                1534011
# 2364  2020-11-04 13:28:22 UTC       Trump        76737                  67833
# 2401  2020-11-04 13:28:22 UTC       Trump       120275                    540
# 2443  2020-11-04 13:28:22 UTC       Trump       461657                 220551
# 2448  2020-11-04 13:28:22 UTC       Trump       515581                   2072
# 2484  2020-11-04 13:28:22 UTC       Biden       377096                 205891
# 2820  2020-11-04 13:28:22 UTC       Trump       618840                1532573
# 2832  2020-11-04 13:28:22 UTC       Biden        95601                  36062
# 2896  2020-11-04 13:28:22 UTC       Trump       356151                 219560
# 2938  2020-11-04 13:28:22 UTC       Trump       116939                  41164
# 2945  2020-11-04 13:28:22 UTC       Trump       710427                   4380
# 3001  2020-11-04 13:28:22 UTC       Trump       672747                 138945
# 3055  2020-11-04 13:28:22 UTC       Trump       208419                 437925
# 3085  2020-11-04 13:28:22 UTC       Biden       116076                  18803
# 3191  2020-11-04 13:28:22 UTC       Biden       388708                 161573
# 3341  2020-11-04 13:28:22 UTC       Biden       802235                 763295
# 3372  2020-11-04 13:28:22 UTC       Trump       307126                   8526
# 3400  2020-11-04 13:28:22 UTC       Biden        20697                    592
# 3405  2020-11-04 13:28:22 UTC       Trump       119839                    422
#
#      Change                 State  Leader Batch Breakdown  \
# 13        0               Alabama                     NaN
# 39        0                Alaska                     NaN
# 125       0               Arizona                     NaN
# 211       0              Arkansas                     NaN
# 355       0            California                     NaN
# 428       0              Colorado                     NaN
# 559       0           Connecticut                     NaN
# 565       0              Delaware                     NaN
# 575       0  District of Columbia                     NaN
# 624       0               Florida                     NaN
# 850       0               Georgia                     NaN
# 854       0                Hawaii                     NaN
# 863       0                 Idaho                     NaN
# 933       0              Illinois                     NaN
# 984       0               Indiana                     NaN
# 1060      0                  Iowa                     NaN
# 1153      0                Kansas                     NaN
# 1210      0              Kentucky                     NaN
# 1225      0             Louisiana                     NaN
# 1321      0                 Maine                     NaN
# 1419      0              Maryland                     NaN
# 1545      0         Massachusetts                     NaN
# 1622      0              Michigan                     NaN
# 1810      0             Minnesota                     NaN
# 1873      0           Mississippi                     NaN
# 1890      0              Missouri                     NaN
# 1910      0               Montana                     NaN
# 1935      0              Nebraska                     NaN
# 1981      0                Nevada                     NaN
# 2046      0         New Hampshire                     NaN
# 2191      0            New Jersey                     NaN
# 2216      0            New Mexico                     NaN
# 2298      0              New York                     NaN
# 2364      0        North Carolina                     NaN
# 2401      0          North Dakota                     NaN
# 2443      0                  Ohio                     NaN
# 2448      0              Oklahoma                     NaN
# 2484      0                Oregon                     NaN
# 2820      0          Pennsylvania                     NaN
# 2832      0          Rhode Island                     NaN
# 2896      0        South Carolina                     NaN
# 2938      0          South Dakota                     NaN
# 2945      0             Tennessee                     NaN
# 3001      0                 Texas                     NaN
# 3055      0                  Utah                     NaN
# 3085      0               Vermont                     NaN
# 3191      0              Virginia                     NaN
# 3341      0            Washington                     NaN
# 3372      0         West Virginia                     NaN
# 3400      0             Wisconsin                     NaN
# 3405      0               Wyoming                     NaN
#
#       Trailer Batch Breakdown Trailer Batch Trend Trailer Hurdle  \
# 13                        NaN                None          387.0
# 39                        NaN                None           57.1
# 125                       NaN                None           58.9
# 211                       NaN                None          871.5
# 355                       NaN                None           84.7
# 428                       NaN                None          113.2
# 559                       NaN                None          112.9
# 565                       NaN                None         2957.8
# 575                       NaN                None          140.0
# 624                       NaN                None          578.3
# 850                       NaN                None           69.3
# 854                       NaN                None          437.0
# 863                       NaN                None          460.0
# 933                       NaN                None           70.2
# 984                       NaN                None          112.7
# 1060                      NaN                None         1508.0
# 1153                      NaN                None          161.5
# 1210                      NaN                None         1785.3
# 1225                      NaN                None        27202.8
# 1321                      NaN                None           70.0
# 1419                      NaN                None           83.6
# 1545                      NaN                None           86.3
# 1622                      NaN                None           52.1
# 1810                      NaN                None          120.1
# 1873                      NaN                None           75.0
# 1890                      NaN                None         1318.1
# 1910                      NaN                None           97.4
# 1935                      NaN                None          160.2
# 1981                      NaN                None           51.8
# 2046                      NaN                None           62.6
# 2191                      NaN                None           70.4
# 2216                      NaN                None          485.7
# 2298                      NaN                None           91.5
# 2364                      NaN                None          107.4
# 2401                      NaN                None        11546.3
# 2443                      NaN                None          156.2
# 2448                      NaN                None        12789.8
# 2484                      NaN                None          144.6
# 2820                      NaN                None           70.4
# 2832                      NaN                None          185.3
# 2896                      NaN                None          132.3
# 2938                      NaN                None          195.9
# 2945                      NaN                None         8316.0
# 3001                      NaN                None          295.7
# 3055                      NaN                None           74.8
# 3085                      NaN                None          369.0
# 3191                      NaN                None          172.6
# 3341                      NaN                None          104.3
# 3372                      NaN                None         1881.7
# 3400                      NaN                None         1828.6
# 3405                      NaN                None        14765.5
#
#       Margin_change_estimate Type
# 13                       NaN
# 39                       NaN
# 125                      NaN
# 211                      NaN
# 355                      NaN
# 428                      NaN
# 559                      NaN
# 565                      NaN
# 575                      NaN
# 624                      NaN
# 850                      NaN
# 854                      NaN
# 863                      NaN
# 933                      NaN
# 984                      NaN
# 1060                     NaN
# 1153                     NaN
# 1210                     NaN
# 1225                     NaN
# 1321                     NaN
# 1419                     NaN
# 1545                     NaN
# 1622                     NaN
# 1810                     NaN
# 1873                     NaN
# 1890                     NaN
# 1910                     NaN
# 1935                     NaN
# 1981                     NaN
# 2046                     NaN
# 2191                     NaN
# 2216                     NaN
# 2298                     NaN
# 2364                     NaN
# 2401                     NaN
# 2443                     NaN
# 2448                     NaN
# 2484                     NaN
# 2820                     NaN
# 2832                     NaN
# 2896                     NaN
# 2938                     NaN
# 2945                     NaN
# 3001                     NaN
# 3055                     NaN
# 3085                     NaN
# 3191                     NaN
# 3341                     NaN
# 3372                     NaN
# 3400                     NaN
# 3405                     NaN

# %%
# Check data types before continuing
result_df.dtypes
# Out:
# Timestamp                   object
# In The Lead                 object
# Vote Margin                  int64
# Votes Remaining (est.)      object
# Change                      object
# State                       object
# Leader Batch Breakdown     float64
# Trailer Batch Breakdown    float64
# Trailer Batch Trend         object
# Trailer Hurdle              object
# Margin_change_estimate     float64
# Type                        object
# dtype: object

# %%
## Need to convert the timestamp to a date and convert the Change column to integer - but I think this needs done after the unknowns are removed.
result_df[['Timestamp']]=result_df[['Timestamp']].apply(pd.to_datetime)  ## could pass in arguments to apply like:  .apply(pd.to_datetime, args=(format = ) )
result_df.dtypes
# Out:
# Timestamp                  datetime64[ns, UTC]
# In The Lead                             object
# Vote Margin                              int64
# Votes Remaining (est.)                  object
# Change                                  object
# State                                   object
# Leader Batch Breakdown                 float64
# Trailer Batch Breakdown                float64
# Trailer Batch Trend                     object
# Trailer Hurdle                          object
# Margin_change_estimate                 float64
# Type                                    object
# dtype: object

# %%
# Throw out Unknowns where the percents do not add to 100%
bad_unknowns = list(result_df[ (result_df['Change']=="Unknown") & (result_df['Leader Batch Breakdown'] + result_df['Trailer Batch Breakdown'] != 100) ].index)
print(bad_unknowns)
# Out:
# [0, 7, 22, 899, 993, 1629, 1632, 1813, 1823, 1878, 2441, 2974, 3096, 3097, 3098, 3383]

# %%
# drop bad Unknown values that can not be replaced with the help of percent values
result_df.drop(bad_unknowns, inplace=True)

# %% [markdown]
# ## Remove Zero Values (not removing last row zeros)

# %%
# remove zero values but modify below so only non-last values are removed.
# zero_check = result_df[(result_df['Change'] == 'Unknown') | (result_df['Change'] == "0")]
results_excludes_last_row = result_df[~result_df.index.isin(last_row_list)]
zero_check = results_excludes_last_row[(results_excludes_last_row['Change'] == "0")]
zero_values = list(zero_check.index)
result_df.drop(zero_values, inplace=True)

# %% [markdown]
# ## Calculate Significant Columns
# * Time Stamp
# * Leader
# * Vote Margin
# * Votes Remaining
# * Batch Total
# * Batch Votes Winner
# * Batch Votes Loser
# * Accum. Votes Winner
# * Accum. Votes Loser
# * Trailer Batch Trend
# * Hurdle Percent Needed

# %%
# checked multiple rows to see if 'Change' column  is useable
result_df.head()
# Out:
#                  Timestamp In The Lead  Vote Margin Votes Remaining (est.)  \
# 0  2021-01-05 15:21:52 UTC       Trump       591546                      4
# 1  2020-12-04 21:12:00 UTC       Trump       591520                Unknown
# 2  2020-11-23 20:33:25 UTC       Trump       591546                      4
# 3  2020-11-23 20:11:23 UTC       Trump       591832                   2521
# 4  2020-11-23 19:48:16 UTC       Trump       591760                   8534
#
#     Change    State  Leader Batch Breakdown  Trailer Batch Breakdown  \
# 0  Unknown  Alabama                     9.1                    109.1
# 1       22  Alabama                     9.1                    109.1
# 2     2476  Alabama                    44.2                     55.8
# 3     5894  Alabama                    50.6                     49.4
# 4     4792  Alabama                    61.2                     38.8
#
#   Trailer Batch Trend Trailer Hurdle  Margin_change_estimate Type
# 0                58.5      7499241.2                     NaN
# 1                58.5           None                     NaN
# 2                58.5      7499241.2                     NaN
# 3                55.0        11954.5                     NaN
# 4                47.8         3566.2                     NaN

# %%
# replace some of the unknown values
batch_leader_votes = result_df['Leader Batch Breakdown']
unknown_check = result_df[(result_df['Change'] == 'Unknown') & ( (batch_leader_votes >= 0) | (batch_leader_votes <= 100) ) ].copy()
for i in range(len(unknown_check)):
    
    raw_value_percent = unknown_check.iloc[i,6]
    winner_batch_percent = float(raw_value_percent)/100
    margin_change_estimate = unknown_check.iloc[i, 10]

#     new_change = round((vote_margin_now - vote_margin_prev)/(winner_batch_percent),0)
    if (raw_value_percent != 0.0):
        new_change = round(margin_change_estimate/winner_batch_percent,0)
    else:
        new_change = round(margin_change_estimate,0)
        print(f"Can not calculate vote margin for row {i}")
        
    unknown_check.iloc[i, 4] = new_change
    unknown_check.iloc[i, 11] = "updated"



# I should store these in a dataframe for future analysis
# Out:
# Can not calculate vote margin for row 19
# Can not calculate vote margin for row 26
# Can not calculate vote margin for row 50
# Can not calculate vote margin for row 51
# Can not calculate vote margin for row 88
# Can not calculate vote margin for row 89
# Can not calculate vote margin for row 94

# %%
unknown_check.head(30)
# Out:
#                      Timestamp In The Lead  Vote Margin  \
# 157  2020-11-16 18:16:52+00:00       Trump       338005
# 192  2020-11-09 17:17:21+00:00       Trump       338978
# 193  2020-11-09 16:41:11+00:00       Trump       338874
# 197  2020-11-06 19:30:23+00:00       Trump       337918
# 198  2020-11-06 19:13:48+00:00       Trump       340363
# 199  2020-11-06 18:51:26+00:00       Trump       340262
# 316  2020-11-09 17:17:21+00:00       Biden      4496538
# 359  2020-11-25 02:25:12+00:00       Biden       439717
# 372  2020-11-16 03:32:50+00:00       Biden       439868
# 435  2020-11-25 02:48:20+00:00       Biden       364750
# 436  2020-11-25 02:37:15+00:00       Biden       364326
# 454  2020-11-09 19:30:10+00:00       Biden       355504
# 587  2020-11-10 14:07:20+00:00       Trump       372707
# 591  2020-11-09 17:17:21+00:00       Trump       373065
# 626  2020-12-05 00:26:57+00:00       Biden        11928
# 627  2020-11-20 22:11:31+00:00       Biden        12670
# 628  2020-11-20 21:57:11+00:00       Biden        13193
# 629  2020-11-20 21:51:12+00:00       Biden        12815
# 631  2020-11-20 21:35:12+00:00       Biden        12602
# 639  2020-11-19 18:55:42+00:00       Biden        13558
# 640  2020-11-19 18:47:41+00:00       Biden        13557
# 810  2020-11-05 02:58:35+00:00       Trump        37322
# 811  2020-11-05 02:51:15+00:00       Trump        37370
# 855  2021-01-05 15:21:52+00:00       Trump       267097
# 857  2020-11-20 23:42:58+00:00       Trump       267097
# 888  2020-11-16 17:48:13+00:00       Biden       984457
# 957  2020-11-11 14:44:44+00:00       Trump       487464
# 1038 2020-11-07 20:17:59+00:00       Trump       138403
# 1053 2020-11-06 13:40:09+00:00       Trump       138669
# 1063 2020-11-25 03:24:13+00:00       Trump       201759
#
#      Votes Remaining (est.)  Change        State  Leader Batch Breakdown  \
# 157                    7175   753.0     Arkansas                    74.0
# 192                    9790   214.0     Arkansas                    48.6
# 193                    5916  3230.0     Arkansas                    75.7
# 197                   11131  3230.0     Arkansas                    75.7
# 198                    6134   207.0     Arkansas                    48.7
# 199                    2257  3000.0     Arkansas                   100.0
# 316                 3092599  7694.0   California                    77.8
# 359                     330    49.0     Colorado                    66.7
# 372                    2119   363.0     Colorado                    42.7
# 435                    1570  3287.0  Connecticut                    12.9
# 436                     858   829.0  Connecticut                    72.1
# 454                   19709   191.0  Connecticut                    84.6
# 587                 Unknown   360.0      Florida                   100.0
# 591                 Unknown     2.0      Florida                   100.0
# 626                 Unknown   796.0      Georgia                    93.2
# 627                 Unknown   666.0      Georgia                    78.5
# 628                 Unknown  2607.0      Georgia                    14.5
# 629                 Unknown   139.0      Georgia                    48.2
# 631                 Unknown  2456.0      Georgia                     5.7
# 639                 Unknown     1.0      Georgia                     0.0
# 640                 Unknown    86.0      Georgia                    58.1
# 810                  122437    93.0      Georgia                    51.8
# 811                  121071  2165.0      Georgia                    75.1
# 855                     140     1.0        Idaho                   100.0
# 857                      48     0.0        Idaho                    50.0
# 888                   97411   342.0     Illinois                    47.3
# 957                    2642     1.0      Indiana                     0.0
# 1038                   4428   381.0         Iowa                    83.1
# 1053                   4190     6.0         Iowa                    77.8
# 1063                  10410   460.0       Kansas                    89.5
#
#       Trailer Batch Breakdown Trailer Batch Trend Trailer Hurdle  \
# 157                      26.0                36.0         2474.0
# 192                      51.4                29.2         1831.7
# 193                      24.3                33.3         2997.4
# 197                      24.3                33.7         1612.1
# 198                      51.3                27.3         2905.2
# 199                       0.0                36.8         7807.4
# 316                      22.2                35.9          124.3
# 359                      33.3                42.4        68523.8
# 372                      57.3                42.4        10717.3
# 435                      87.1                37.8        11849.3
# 436                      27.9                39.8        21615.8
# 454                      15.4                41.7          966.1
# 587                       0.0                54.3           None
# 591                       0.0                53.6           None
# 626                       6.8                36.8           None
# 627                      21.5                36.5           None
# 628                      85.5                35.0           None
# 629                      51.8                35.7           None
# 631                      94.3                35.7           None
# 639                     100.0                32.4           None
# 640                      41.9                32.3           None
# 810                      48.2                68.8           65.4
# 811                      24.9                73.2           65.6
# 855                       0.0                13.2        98489.5
# 857                      50.0                13.2       287165.2
# 888                      52.7                13.4          565.1
# 957                     100.0                67.5         9464.1
# 1038                     16.9                None         1645.0
# 1053                     22.2                65.6         1738.9
# 1063                     10.5                54.9         1043.3
#
#       Margin_change_estimate     Type
# 157                    557.0  updated
# 192                    104.0  updated
# 193                   2445.0  updated
# 197                   2445.0  updated
# 198                    101.0  updated
# 199                   3000.0  updated
# 316                   5986.0  updated
# 359                     33.0  updated
# 372                    155.0  updated
# 435                    424.0  updated
# 436                    598.0  updated
# 454                    162.0  updated
# 587                    360.0  updated
# 591                      2.0  updated
# 626                    742.0  updated
# 627                    523.0  updated
# 628                    378.0  updated
# 629                     67.0  updated
# 631                    140.0  updated
# 639                      1.0  updated
# 640                     50.0  updated
# 810                     48.0  updated
# 811                   1626.0  updated
# 855                      1.0  updated
# 857                      0.0  updated
# 888                    162.0  updated
# 957                      1.0  updated
# 1038                   317.0  updated
# 1053                     5.0  updated
# 1063                   412.0  updated

# %%
restored = pd.concat([result_df, unknown_check])

# %%
filtered_df = restored[~restored.index.duplicated(keep='last')]
filtered_df.head()
# Out:
#                   Timestamp In The Lead  Vote Margin Votes Remaining (est.)  \
# 1 2020-12-04 21:12:00+00:00       Trump       591520                Unknown
# 2 2020-11-23 20:33:25+00:00       Trump       591546                      4
# 3 2020-11-23 20:11:23+00:00       Trump       591832                   2521
# 4 2020-11-23 19:48:16+00:00       Trump       591760                   8534
# 6 2020-11-06 22:26:37+00:00       Trump       590686                  13386
#
#   Change    State  Leader Batch Breakdown  Trailer Batch Breakdown  \
# 1     22  Alabama                     9.1                    109.1
# 2   2476  Alabama                    44.2                     55.8
# 3   5894  Alabama                    50.6                     49.4
# 4   4792  Alabama                    61.2                     38.8
# 6  12548  Alabama                    28.6                     71.4
#
#   Trailer Batch Trend Trailer Hurdle  Margin_change_estimate Type
# 1                58.5           None                    26.0
# 2                58.5      7499241.2                   286.0
# 3                55.0        11954.5                    72.0
# 4                47.8         3566.2                  1074.0
# 6                44.9         2287.6                  5360.0

# %%
filtered_df[ filtered_df['State'] == 'Alabama']
# Out:
#                    Timestamp In The Lead  Vote Margin Votes Remaining (est.)  \
# 1  2020-12-04 21:12:00+00:00       Trump       591520                Unknown
# 2  2020-11-23 20:33:25+00:00       Trump       591546                      4
# 3  2020-11-23 20:11:23+00:00       Trump       591832                   2521
# 4  2020-11-23 19:48:16+00:00       Trump       591760                   8534
# 6  2020-11-06 22:26:37+00:00       Trump       590686                  13386
# 8  2020-11-04 21:12:19+00:00       Trump       595572                  25662
# 9  2020-11-04 21:00:38+00:00       Trump       595576                  25815
# 10 2020-11-04 20:28:27+00:00       Trump       595034                  28763
# 11 2020-11-04 20:23:38+00:00       Trump       597108                  28830
# 12 2020-11-04 17:16:47+00:00       Trump       586810                  43805
# 13 2020-11-04 13:28:22+00:00       Trump       618344                  93031
#
#    Change    State  Leader Batch Breakdown  Trailer Batch Breakdown  \
# 1      22  Alabama                     9.1                    109.1
# 2    2476  Alabama                    44.2                     55.8
# 3    5894  Alabama                    50.6                     49.4
# 4    4792  Alabama                    61.2                     38.8
# 6   12548  Alabama                    28.6                     71.4
# 8      10  Alabama                    30.0                     70.0
# 9    2938  Alabama                    59.2                     40.8
# 10     54  Alabama                  1870.4                   1970.4
# 11  13958  Alabama                    86.9                     13.1
# 12  48782  Alabama                    17.7                     82.3
# 13      0  Alabama                     NaN                      NaN
#
#    Trailer Batch Trend Trailer Hurdle  Margin_change_estimate Type
# 1                 58.5           None                    26.0
# 2                 58.5      7499241.2                   286.0
# 3                 55.0        11954.5                    72.0
# 4                 47.8         3566.2                  1074.0
# 6                 44.9         2287.6                  5360.0
# 8                 49.4         1226.9                     4.0
# 9                 49.5         1219.9                   542.0
# 10                53.5         1099.0                  2074.0
# 11                50.1         1100.3                 10298.0
# 12                82.3          729.3                 31534.0
# 13                None          387.0                     NaN

# %%
filtered_df.dtypes
# Out:
# Timestamp                  datetime64[ns, UTC]
# In The Lead                             object
# Vote Margin                              int64
# Votes Remaining (est.)                  object
# Change                                  object
# State                                   object
# Leader Batch Breakdown                 float64
# Trailer Batch Breakdown                float64
# Trailer Batch Trend                     object
# Trailer Hurdle                          object
# Margin_change_estimate                 float64
# Type                                    object
# dtype: object

# %%
result_df = filtered_df.copy()

# %%
result_df[['Change','Trailer Batch Trend', 'Trailer Hurdle']] = result_df[['Change','Trailer Batch Trend', 'Trailer Hurdle']].apply(pd.to_numeric)

# %%
result_df.dtypes
# Out:
# Timestamp                  datetime64[ns, UTC]
# In The Lead                             object
# Vote Margin                              int64
# Votes Remaining (est.)                  object
# Change                                 float64
# State                                   object
# Leader Batch Breakdown                 float64
# Trailer Batch Breakdown                float64
# Trailer Batch Trend                    float64
# Trailer Hurdle                         float64
# Margin_change_estimate                 float64
# Type                                    object
# dtype: object

# %%
result_df.sort_values(by=['State', 'Timestamp'], ascending=[True, False], inplace=True)

# %%
# needed for groupby setup so we have access to index number within the df
result_df.reset_index(inplace=True, drop=True)
result_df.reset_index(inplace=True)

# %%
result_df.head(10)
# Out:
#    index                 Timestamp In The Lead  Vote Margin  \
# 0      0 2020-12-04 21:12:00+00:00       Trump       591520
# 1      1 2020-11-23 20:33:25+00:00       Trump       591546
# 2      2 2020-11-23 20:11:23+00:00       Trump       591832
# 3      3 2020-11-23 19:48:16+00:00       Trump       591760
# 4      4 2020-11-06 22:26:37+00:00       Trump       590686
# 5      5 2020-11-04 21:12:19+00:00       Trump       595572
# 6      6 2020-11-04 21:00:38+00:00       Trump       595576
# 7      7 2020-11-04 20:28:27+00:00       Trump       595034
# 8      8 2020-11-04 20:23:38+00:00       Trump       597108
# 9      9 2020-11-04 17:16:47+00:00       Trump       586810
#
#   Votes Remaining (est.)   Change    State  Leader Batch Breakdown  \
# 0                Unknown     22.0  Alabama                     9.1
# 1                      4   2476.0  Alabama                    44.2
# 2                   2521   5894.0  Alabama                    50.6
# 3                   8534   4792.0  Alabama                    61.2
# 4                  13386  12548.0  Alabama                    28.6
# 5                  25662     10.0  Alabama                    30.0
# 6                  25815   2938.0  Alabama                    59.2
# 7                  28763     54.0  Alabama                  1870.4
# 8                  28830  13958.0  Alabama                    86.9
# 9                  43805  48782.0  Alabama                    17.7
#
#    Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 0                    109.1                 58.5             NaN
# 1                     55.8                 58.5       7499241.2
# 2                     49.4                 55.0         11954.5
# 3                     38.8                 47.8          3566.2
# 4                     71.4                 44.9          2287.6
# 5                     70.0                 49.4          1226.9
# 6                     40.8                 49.5          1219.9
# 7                   1970.4                 53.5          1099.0
# 8                     13.1                 50.1          1100.3
# 9                     82.3                 82.3           729.3
#
#    Margin_change_estimate Type
# 0                    26.0
# 1                   286.0
# 2                    72.0
# 3                  1074.0
# 4                  5360.0
# 5                     4.0
# 6                   542.0
# 7                  2074.0
# 8                 10298.0
# 9                 31534.0

# %%
len(result_df)
# Out:
# 3060

# %%
last_rows = list(result_df.groupby('State').last()['index'])
print(last_rows)
# Out:
# [10, 26, 112, 194, 285, 353, 461, 467, 477, 494, 711, 715, 722, 785, 833, 903, 963, 1014, 1029, 1121, 1219, 1345, 1405, 1582, 1640, 1650, 1670, 1681, 1727, 1789, 1934, 1955, 2027, 2086, 2120, 2160, 2165, 2198, 2522, 2534, 2592, 2633, 2640, 2688, 2742, 2772, 2861, 3011, 3028, 3054, 3059]

# %%
first_rows = list(result_df.groupby('State').first()['index'])
print(first_rows)
# Out:
# [0, 11, 27, 113, 195, 286, 354, 462, 468, 478, 495, 712, 716, 723, 786, 834, 904, 964, 1015, 1030, 1122, 1220, 1346, 1406, 1583, 1641, 1651, 1671, 1682, 1728, 1790, 1935, 1956, 2028, 2087, 2121, 2161, 2166, 2199, 2523, 2535, 2593, 2634, 2641, 2689, 2743, 2773, 2862, 3012, 3029, 3055]

# %%
result_df[['Batch Votes Winner', 'Batch Votes Loser', 'Accum. Votes Winner', 'Accum. Votes Loser']] = ""
result_df.head(3)
# Out:
#    index                 Timestamp In The Lead  Vote Margin  \
# 0      0 2020-12-04 21:12:00+00:00       Trump       591520
# 1      1 2020-11-23 20:33:25+00:00       Trump       591546
# 2      2 2020-11-23 20:11:23+00:00       Trump       591832
#
#   Votes Remaining (est.)  Change    State  Leader Batch Breakdown  \
# 0                Unknown    22.0  Alabama                     9.1
# 1                      4  2476.0  Alabama                    44.2
# 2                   2521  5894.0  Alabama                    50.6
#
#    Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 0                    109.1                 58.5             NaN
# 1                     55.8                 58.5       7499241.2
# 2                     49.4                 55.0         11954.5
#
#    Margin_change_estimate Type Batch Votes Winner Batch Votes Loser  \
# 0                    26.0
# 1                   286.0
# 2                    72.0
#
#   Accum. Votes Winner Accum. Votes Loser
# 0
# 1
# 2

# %%
result_df[['Batch Votes Winner', 'Batch Votes Loser', 'Accum. Votes Winner', 'Accum. Votes Loser']] = result_df[['Batch Votes Winner', 'Batch Votes Loser', 'Accum. Votes Winner', 'Accum. Votes Loser']].apply(pd.to_numeric)

result_df.head(3)
# Out:
#    index                 Timestamp In The Lead  Vote Margin  \
# 0      0 2020-12-04 21:12:00+00:00       Trump       591520
# 1      1 2020-11-23 20:33:25+00:00       Trump       591546
# 2      2 2020-11-23 20:11:23+00:00       Trump       591832
#
#   Votes Remaining (est.)  Change    State  Leader Batch Breakdown  \
# 0                Unknown    22.0  Alabama                     9.1
# 1                      4  2476.0  Alabama                    44.2
# 2                   2521  5894.0  Alabama                    50.6
#
#    Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 0                    109.1                 58.5             NaN
# 1                     55.8                 58.5       7499241.2
# 2                     49.4                 55.0         11954.5
#
#    Margin_change_estimate Type  Batch Votes Winner  Batch Votes Loser  \
# 0                    26.0                      NaN                NaN
# 1                   286.0                      NaN                NaN
# 2                    72.0                      NaN                NaN
#
#    Accum. Votes Winner  Accum. Votes Loser
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN

# %%
## result_df.drop(result_df.columns[[11]], axis='columns', inplace=True)

# %%
result_df.dtypes
# Out:
# index                                    int64
# Timestamp                  datetime64[ns, UTC]
# In The Lead                             object
# Vote Margin                              int64
# Votes Remaining (est.)                  object
# Change                                 float64
# State                                   object
# Leader Batch Breakdown                 float64
# Trailer Batch Breakdown                float64
# Trailer Batch Trend                    float64
# Trailer Hurdle                         float64
# Margin_change_estimate                 float64
# Type                                    object
# Batch Votes Winner                     float64
# Batch Votes Loser                      float64
# Accum. Votes Winner                    float64
# Accum. Votes Loser                     float64
# dtype: object

# %%
# Need to remove the rows of change data that is smaller than the vote margin change - that data doesn't make sense
bad_data_rows = []
for i in range(len(result_df)-1):
    if i in last_rows:
        ## Skip = Not valuable data
        continue
    else:
        change = result_df.iloc[i,5]
        vote_margin_now = int(result_df.iloc[i,3])
        vote_margin_prev = int(result_df.iloc[i+1,3])
        
        if change > abs(vote_margin_now - vote_margin_prev):
            ## Skip = Good Data
            continue
        else: 
            bad_data_rows.append(i)

# %%
len(bad_data_rows)
# Out:
# 384

# %%
bad_data_rows[0:10]
# Out:
# [0, 7, 12, 13, 27, 28, 32, 36, 41, 45]

# %%
result_df.drop(bad_data_rows, inplace=True, )

# %%
result_df.head(30)
# Out:
#     index                 Timestamp In The Lead  Vote Margin  \
# 1       1 2020-11-23 20:33:25+00:00       Trump       591546
# 2       2 2020-11-23 20:11:23+00:00       Trump       591832
# 3       3 2020-11-23 19:48:16+00:00       Trump       591760
# 4       4 2020-11-06 22:26:37+00:00       Trump       590686
# 5       5 2020-11-04 21:12:19+00:00       Trump       595572
# 6       6 2020-11-04 21:00:38+00:00       Trump       595576
# 8       8 2020-11-04 20:23:38+00:00       Trump       597108
# 9       9 2020-11-04 17:16:47+00:00       Trump       586810
# 10     10 2020-11-04 13:28:22+00:00       Trump       618344
# 11     11 2020-12-02 15:22:19+00:00       Trump        36173
# 14     14 2020-11-25 02:25:12+00:00       Trump        36041
# 15     15 2020-11-19 13:18:50+00:00       Trump        35906
# 16     16 2020-11-16 17:16:11+00:00       Trump        35507
# 17     17 2020-11-15 18:50:50+00:00       Trump        36695
# 18     18 2020-11-14 02:45:23+00:00       Trump        36043
# 19     19 2020-11-13 13:58:29+00:00       Trump        35163
# 20     20 2020-11-13 02:28:29+00:00       Trump        37721
# 21     21 2020-11-12 16:47:02+00:00       Trump        44650
# 22     22 2020-11-11 13:19:23+00:00       Trump        46544
# 23     23 2020-11-11 02:51:01+00:00       Trump        47767
# 24     24 2020-11-09 19:14:19+00:00       Trump        54598
# 25     25 2020-11-04 18:40:57+00:00       Trump        51382
# 26     26 2020-11-04 13:28:22+00:00       Trump        35241
# 29     29 2020-11-16 18:51:33+00:00       Biden        10457
# 30     30 2020-11-15 01:35:27+00:00       Biden        10377
# 31     31 2020-11-14 23:57:27+00:00       Biden        10210
# 33     33 2020-11-14 01:21:23+00:00       Biden        10016
# 34     34 2020-11-14 00:59:43+00:00       Biden        10136
# 35     35 2020-11-14 00:30:24+00:00       Biden        11022
# 37     37 2020-11-13 18:16:31+00:00       Biden        10988
#
#    Votes Remaining (est.)   Change    State  Leader Batch Breakdown  \
# 1                       4   2476.0  Alabama                    44.2
# 2                    2521   5894.0  Alabama                    50.6
# 3                    8534   4792.0  Alabama                    61.2
# 4                   13386  12548.0  Alabama                    28.6
# 5                   25662     10.0  Alabama                    30.0
# 6                   25815   2938.0  Alabama                    59.2
# 8                   28830  13958.0  Alabama                    86.9
# 9                   43805  48782.0  Alabama                    17.7
# 10                  93031      0.0  Alabama                     NaN
# 11                  31816    587.0   Alaska                    22.7
# 14                  32544    432.0   Alaska                    13.7
# 15                  34550   6977.0   Alaska                    52.9
# 16                  41873   9404.0   Alaska                    43.7
# 17                  51823   4510.0   Alaska                    57.2
# 18                  56557  10814.0   Alaska                    54.1
# 19                  66152  11116.0   Alaska                    38.5
# 20                  79313  24451.0   Alaska                    35.8
# 21                 104558  25032.0   Alaska                    46.2
# 22                 130363  19943.0   Alaska                    46.9
# 23                 151112  47671.0   Alaska                    42.8
# 24                 200376  18010.0   Alaska                    58.9
# 25                 219315  38323.0   Alaska                    71.1
# 26                 258871      0.0   Alaska                     NaN
# 29                     18     98.0  Arizona                    90.8
# 30                    116    421.0  Arizona                    69.8
# 31                    541    344.0  Arizona                    78.2
# 33                    891   1416.0  Arizona                    45.8
# 34                   2345   1610.0  Arizona                    22.5
# 35                   3993    406.0  Arizona                    54.4
# 37                   4419   3598.0  Arizona                    43.8
#
#     Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 1                      55.8                 58.5       7499241.2
# 2                      49.4                 55.0         11954.5
# 3                      38.8                 47.8          3566.2
# 4                      71.4                 44.9          2287.6
# 5                      70.0                 49.4          1226.9
# 6                      40.8                 49.5          1219.9
# 8                      13.1                 50.1          1100.3
# 9                      82.3                 82.3           729.3
# 10                      NaN                  NaN           387.0
# 11                     77.3                 49.4           109.5
# 14                     86.3                 49.6           107.9
# 15                     47.1                 49.0           104.4
# 16                     56.3                 51.4            94.3
# 17                     42.8                 53.4            87.0
# 18                     45.9                 56.6            83.3
# 19                     61.5                 63.2            77.8
# 20                     64.2                 62.2            74.9
# 21                     53.8                 53.7            72.3
# 22                     53.1                 54.4            68.7
# 23                     57.2                 57.2            66.5
# 24                     41.1                 36.2            64.3
# 25                     28.9                 28.9            62.3
# 26                      NaN                  NaN            57.1
# 29                      9.2                 53.7         29563.3
# 30                     30.2                 53.9          4594.6
# 31                     21.8                 54.2          1008.8
# 33                     54.2                 54.6           621.1
# 34                     77.5                 54.5           269.6
# 35                     45.6                 53.0           190.2
# 37                     56.2                 53.1           176.3
#
#     Margin_change_estimate Type  Batch Votes Winner  Batch Votes Loser  \
# 1                    286.0                      NaN                NaN
# 2                     72.0                      NaN                NaN
# 3                   1074.0                      NaN                NaN
# 4                   5360.0                      NaN                NaN
# 5                      4.0                      NaN                NaN
# 6                    542.0                      NaN                NaN
# 8                  10298.0                      NaN                NaN
# 9                  31534.0                      NaN                NaN
# 10                     NaN                      NaN                NaN
# 11                   321.0                      NaN                NaN
# 14                   314.0                      NaN                NaN
# 15                   399.0                      NaN                NaN
# 16                  1188.0                      NaN                NaN
# 17                   652.0                      NaN                NaN
# 18                   880.0                      NaN                NaN
# 19                  2558.0                      NaN                NaN
# 20                  6929.0                      NaN                NaN
# 21                  1894.0                      NaN                NaN
# 22                  1223.0                      NaN                NaN
# 23                  6831.0                      NaN                NaN
# 24                  3216.0                      NaN                NaN
# 25                 16141.0                      NaN                NaN
# 26                     NaN                      NaN                NaN
# 29                    80.0                      NaN                NaN
# 30                   167.0                      NaN                NaN
# 31                   194.0                      NaN                NaN
# 33                   120.0                      NaN                NaN
# 34                   886.0                      NaN                NaN
# 35                    36.0                      NaN                NaN
# 37                   446.0                      NaN                NaN
#
#     Accum. Votes Winner  Accum. Votes Loser
# 1                   NaN                 NaN
# 2                   NaN                 NaN
# 3                   NaN                 NaN
# 4                   NaN                 NaN
# 5                   NaN                 NaN
# 6                   NaN                 NaN
# 8                   NaN                 NaN
# 9                   NaN                 NaN
# 10                  NaN                 NaN
# 11                  NaN                 NaN
# 14                  NaN                 NaN
# 15                  NaN                 NaN
# 16                  NaN                 NaN
# 17                  NaN                 NaN
# 18                  NaN                 NaN
# 19                  NaN                 NaN
# 20                  NaN                 NaN
# 21                  NaN                 NaN
# 22                  NaN                 NaN
# 23                  NaN                 NaN
# 24                  NaN                 NaN
# 25                  NaN                 NaN
# 26                  NaN                 NaN
# 29                  NaN                 NaN
# 30                  NaN                 NaN
# 31                  NaN                 NaN
# 33                  NaN                 NaN
# 34                  NaN                 NaN
# 35                  NaN                 NaN
# 37                  NaN                 NaN

# %%
# find if any percentages are greater than 100% and remove
df33 = result_df[ (result_df['Trailer Batch Breakdown'] > 100) | (result_df['Trailer Batch Breakdown'] < 0)]
df33.head()
# Out:
# Empty DataFrame
# Columns: [index, Timestamp, In The Lead, Vote Margin, Votes Remaining (est.), Change, State, Leader Batch Breakdown, Trailer Batch Breakdown, Trailer Batch Trend, Trailer Hurdle, Margin_change_estimate, Type, Batch Votes Winner, Batch Votes Loser, Accum. Votes Winner, Accum. Votes Loser]
# Index: []

# %%
if len(df33)>0:
    result_df.drop(list(df33.index), inplace=True)
else:
    print("No Values greater than 100")
# Out:
# No Values greater than 100

# %%
temp_store = result_df

# %%
result_df = temp_store

# %%
# Reset index so index goes from 1,2,...,N
result_df.drop('index', axis='columns', inplace=True)

# %%
result_df.reset_index(drop=True, inplace=True)

# %%
result_df.reset_index(inplace=True)
result_df.head(2)
# Out:
#    index                 Timestamp In The Lead  Vote Margin  \
# 0      0 2020-11-23 20:33:25+00:00       Trump       591546
# 1      1 2020-11-23 20:11:23+00:00       Trump       591832
#
#   Votes Remaining (est.)  Change    State  Leader Batch Breakdown  \
# 0                      4  2476.0  Alabama                    44.2
# 1                   2521  5894.0  Alabama                    50.6
#
#    Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 0                     55.8                 58.5       7499241.2
# 1                     49.4                 55.0         11954.5
#
#    Margin_change_estimate Type  Batch Votes Winner  Batch Votes Loser  \
# 0                   286.0                      NaN                NaN
# 1                    72.0                      NaN                NaN
#
#    Accum. Votes Winner  Accum. Votes Loser
# 0                  NaN                 NaN
# 1                  NaN                 NaN

# %%
#result_df.head(10)

# %%
result_df.dtypes
# Out:
# index                                    int64
# Timestamp                  datetime64[ns, UTC]
# In The Lead                             object
# Vote Margin                              int64
# Votes Remaining (est.)                  object
# Change                                 float64
# State                                   object
# Leader Batch Breakdown                 float64
# Trailer Batch Breakdown                float64
# Trailer Batch Trend                    float64
# Trailer Hurdle                         float64
# Margin_change_estimate                 float64
# Type                                    object
# Batch Votes Winner                     float64
# Batch Votes Loser                      float64
# Accum. Votes Winner                    float64
# Accum. Votes Loser                     float64
# dtype: object

# %%
first_rows = list(result_df.groupby('State').first()['index'])
print(first_rows)
# Out:
# [0, 9, 23, 98, 171, 262, 326, 417, 421, 431, 445, 636, 640, 644, 701, 743, 803, 860, 906, 910, 1001, 1058, 1173, 1226, 1368, 1424, 1431, 1449, 1458, 1492, 1549, 1685, 1705, 1776, 1834, 1861, 1900, 1902, 1934, 2242, 2250, 2304, 2321, 2327, 2370, 2401, 2410, 2490, 2635, 2652, 2673]

# %%
last_rows = list(result_df.groupby('State').last()['index'])
print(last_rows)
# Out:
# [8, 22, 97, 170, 261, 325, 416, 420, 430, 444, 635, 639, 643, 700, 742, 802, 859, 905, 909, 1000, 1057, 1172, 1225, 1367, 1423, 1430, 1448, 1457, 1491, 1548, 1684, 1704, 1775, 1833, 1860, 1899, 1901, 1933, 2241, 2249, 2303, 2320, 2326, 2369, 2400, 2409, 2489, 2634, 2651, 2672, 2675]

# %%
state_index = 0
for i in range(len(result_df)-1):
    if i in first_rows:
        winner_final_votes = summary_df.iloc[state_index,3].astype(int)
        loser_final_votes = summary_df.iloc[state_index, 6].astype(int)
        
        #Accum. Votes Winner
        result_df.iloc[i,15] = winner_final_votes.astype(int)
                
        #Accum. Votes Loser
        result_df.iloc[i,16] = loser_final_votes.astype(int)
        
        # Next state
        state_index += 1
        
        # Calculate Batch Votes
        change = int(result_df.iloc[i,5])
        vote_margin_now = int(result_df.iloc[i,3])
        vote_margin_prev = int(result_df.iloc[i+1,3])
        
        # Batch Votes Loser
        bvl = ( change - vote_margin_now + vote_margin_prev )/2
        result_df.iloc[i,14] = bvl
        
        # Batch Votes Winner
        bvw = bvl + vote_margin_now - vote_margin_prev
        result_df.iloc[i,13] = bvw
        
    elif i in last_rows:
        change = int(result_df.iloc[i,5])
        loser_batch_percent = result_df.iloc[i,8]/100
        winner_batch_percent = result_df.iloc[i,7]/100
        
        # Batch Votes Loser
        result_df.iloc[i,14] = round(result_df.iloc[i-1,16] - result_df.iloc[i-1,14],0)
        
        # Batch Votes Winner
        result_df.iloc[i,13] = round(result_df.iloc[i-1,15] - result_df.iloc[i-1,13],0)

        # Accum Winner
        result_df.iloc[i,15] = round(result_df.iloc[i-1,15] - result_df.iloc[i-1,13],0)
        
        # Accum Loser
        result_df.iloc[i,16] = round(result_df.iloc[i-1,16] - result_df.iloc[i-1,14],0)
        
    else:
        change = int(result_df.iloc[i,5])
        vote_margin_now = int(result_df.iloc[i,3])
        vote_margin_prev = int(result_df.iloc[i+1,3])
        
        # Batch Votes Loser
        bvl = ( change - vote_margin_now + vote_margin_prev )/2
        result_df.iloc[i,14] = bvl
        
        # Batch Votes Winner
        bvw = bvl + vote_margin_now - vote_margin_prev
        result_df.iloc[i,13] = bvw

        # Accum Winner
        result_df.iloc[i,15] = result_df.iloc[i-1,15] - bvw
        
        # Accum Loser
        result_df.iloc[i,16] = result_df.iloc[i-1,16] - bvl

# %%
result_df.head(30)
# Out:
#     index                 Timestamp In The Lead  Vote Margin  \
# 0       0 2020-11-23 20:33:25+00:00       Trump       591546
# 1       1 2020-11-23 20:11:23+00:00       Trump       591832
# 2       2 2020-11-23 19:48:16+00:00       Trump       591760
# 3       3 2020-11-06 22:26:37+00:00       Trump       590686
# 4       4 2020-11-04 21:12:19+00:00       Trump       595572
# 5       5 2020-11-04 21:00:38+00:00       Trump       595576
# 6       6 2020-11-04 20:23:38+00:00       Trump       597108
# 7       7 2020-11-04 17:16:47+00:00       Trump       586810
# 8       8 2020-11-04 13:28:22+00:00       Trump       618344
# 9       9 2020-12-02 15:22:19+00:00       Trump        36173
# 10     10 2020-11-25 02:25:12+00:00       Trump        36041
# 11     11 2020-11-19 13:18:50+00:00       Trump        35906
# 12     12 2020-11-16 17:16:11+00:00       Trump        35507
# 13     13 2020-11-15 18:50:50+00:00       Trump        36695
# 14     14 2020-11-14 02:45:23+00:00       Trump        36043
# 15     15 2020-11-13 13:58:29+00:00       Trump        35163
# 16     16 2020-11-13 02:28:29+00:00       Trump        37721
# 17     17 2020-11-12 16:47:02+00:00       Trump        44650
# 18     18 2020-11-11 13:19:23+00:00       Trump        46544
# 19     19 2020-11-11 02:51:01+00:00       Trump        47767
# 20     20 2020-11-09 19:14:19+00:00       Trump        54598
# 21     21 2020-11-04 18:40:57+00:00       Trump        51382
# 22     22 2020-11-04 13:28:22+00:00       Trump        35241
# 23     23 2020-11-16 18:51:33+00:00       Biden        10457
# 24     24 2020-11-15 01:35:27+00:00       Biden        10377
# 25     25 2020-11-14 23:57:27+00:00       Biden        10210
# 26     26 2020-11-14 01:21:23+00:00       Biden        10016
# 27     27 2020-11-14 00:59:43+00:00       Biden        10136
# 28     28 2020-11-14 00:30:24+00:00       Biden        11022
# 29     29 2020-11-13 18:16:31+00:00       Biden        10988
#
#    Votes Remaining (est.)   Change    State  Leader Batch Breakdown  \
# 0                       4   2476.0  Alabama                    44.2
# 1                    2521   5894.0  Alabama                    50.6
# 2                    8534   4792.0  Alabama                    61.2
# 3                   13386  12548.0  Alabama                    28.6
# 4                   25662     10.0  Alabama                    30.0
# 5                   25815   2938.0  Alabama                    59.2
# 6                   28830  13958.0  Alabama                    86.9
# 7                   43805  48782.0  Alabama                    17.7
# 8                   93031      0.0  Alabama                     NaN
# 9                   31816    587.0   Alaska                    22.7
# 10                  32544    432.0   Alaska                    13.7
# 11                  34550   6977.0   Alaska                    52.9
# 12                  41873   9404.0   Alaska                    43.7
# 13                  51823   4510.0   Alaska                    57.2
# 14                  56557  10814.0   Alaska                    54.1
# 15                  66152  11116.0   Alaska                    38.5
# 16                  79313  24451.0   Alaska                    35.8
# 17                 104558  25032.0   Alaska                    46.2
# 18                 130363  19943.0   Alaska                    46.9
# 19                 151112  47671.0   Alaska                    42.8
# 20                 200376  18010.0   Alaska                    58.9
# 21                 219315  38323.0   Alaska                    71.1
# 22                 258871      0.0   Alaska                     NaN
# 23                     18     98.0  Arizona                    90.8
# 24                    116    421.0  Arizona                    69.8
# 25                    541    344.0  Arizona                    78.2
# 26                    891   1416.0  Arizona                    45.8
# 27                   2345   1610.0  Arizona                    22.5
# 28                   3993    406.0  Arizona                    54.4
# 29                   4419   3598.0  Arizona                    43.8
#
#     Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 0                      55.8                 58.5       7499241.2
# 1                      49.4                 55.0         11954.5
# 2                      38.8                 47.8          3566.2
# 3                      71.4                 44.9          2287.6
# 4                      70.0                 49.4          1226.9
# 5                      40.8                 49.5          1219.9
# 6                      13.1                 50.1          1100.3
# 7                      82.3                 82.3           729.3
# 8                       NaN                  NaN           387.0
# 9                      77.3                 49.4           109.5
# 10                     86.3                 49.6           107.9
# 11                     47.1                 49.0           104.4
# 12                     56.3                 51.4            94.3
# 13                     42.8                 53.4            87.0
# 14                     45.9                 56.6            83.3
# 15                     61.5                 63.2            77.8
# 16                     64.2                 62.2            74.9
# 17                     53.8                 53.7            72.3
# 18                     53.1                 54.4            68.7
# 19                     57.2                 57.2            66.5
# 20                     41.1                 36.2            64.3
# 21                     28.9                 28.9            62.3
# 22                      NaN                  NaN            57.1
# 23                      9.2                 53.7         29563.3
# 24                     30.2                 53.9          4594.6
# 25                     21.8                 54.2          1008.8
# 26                     54.2                 54.6           621.1
# 27                     77.5                 54.5           269.6
# 28                     45.6                 53.0           190.2
# 29                     56.2                 53.1           176.3
#
#     Margin_change_estimate Type  Batch Votes Winner  Batch Votes Loser  \
# 0                    286.0                   1095.0             1381.0
# 1                     72.0                   2983.0             2911.0
# 2                   1074.0                   2933.0             1859.0
# 3                   5360.0                   3831.0             8717.0
# 4                      4.0                      3.0                7.0
# 5                    542.0                    703.0             2235.0
# 6                  10298.0                  12128.0             1830.0
# 7                  31534.0                   8624.0            40158.0
# 8                      NaN                1401341.0           751749.0
# 9                    321.0                    359.5              227.5
# 10                   314.0                    283.5              148.5
# 11                   399.0                   3688.0             3289.0
# 12                  1188.0                   4108.0             5296.0
# 13                   652.0                   2581.0             1929.0
# 14                   880.0                   5847.0             4967.0
# 15                  2558.0                   4279.0             6837.0
# 16                  6929.0                   8761.0            15690.0
# 17                  1894.0                  11569.0            13463.0
# 18                  1223.0                   9360.0            10583.0
# 19                  6831.0                  20420.0            27251.0
# 20                  3216.0                  10613.0             7397.0
# 21                 16141.0                  27232.0            11091.0
# 22                     NaN                  53978.0            34746.0
# 23                    80.0                     89.0                9.0
# 24                   167.0                    294.0              127.0
# 25                   194.0                    269.0               75.0
# 26                   120.0                    648.0              768.0
# 27                   886.0                    362.0             1248.0
# 28                    36.0                    220.0              186.0
# 29                   446.0                   1576.0             2022.0
#
#     Accum. Votes Winner  Accum. Votes Loser
# 0             1441170.0            849624.0
# 1             1438187.0            846713.0
# 2             1435254.0            844854.0
# 3             1431423.0            836137.0
# 4             1431420.0            836130.0
# 5             1430717.0            833895.0
# 6             1418589.0            832065.0
# 7             1409965.0            791907.0
# 8             1401341.0            751749.0
# 9              189951.0            153778.0
# 10             189667.5            153629.5
# 11             185979.5            150340.5
# 12             181871.5            145044.5
# 13             179290.5            143115.5
# 14             173443.5            138148.5
# 15             169164.5            131311.5
# 16             160403.5            115621.5
# 17             148834.5            102158.5
# 18             139474.5             91575.5
# 19             119054.5             64324.5
# 20             108441.5             56927.5
# 21              81209.5             45836.5
# 22              53978.0             34746.0
# 23            1672143.0           1661686.0
# 24            1671849.0           1661559.0
# 25            1671580.0           1661484.0
# 26            1670932.0           1660716.0
# 27            1670570.0           1659468.0
# 28            1670350.0           1659282.0
# 29            1668774.0           1657260.0

# %%
result_df[result_df['Batch Votes Winner'].isna()]
# Out:
#       index                 Timestamp In The Lead  Vote Margin  \
# 2675   2675 2020-11-04 13:28:22+00:00       Trump       119839
#
#      Votes Remaining (est.)  Change    State  Leader Batch Breakdown  \
# 2675                    422     0.0  Wyoming                     NaN
#
#       Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 2675                      NaN                  NaN         14765.5
#
#       Margin_change_estimate Type  Batch Votes Winner  Batch Votes Loser  \
# 2675                     NaN                      NaN                NaN
#
#       Accum. Votes Winner  Accum. Votes Loser
# 2675                  NaN                 NaN

# %%
result_df[2670: 2676]
# Out:
#       index                 Timestamp In The Lead  Vote Margin  \
# 2670   2670 2020-11-04 18:30:33+00:00       Biden        20509
# 2671   2671 2020-11-04 17:57:21+00:00       Biden        20533
# 2672   2672 2020-11-04 13:28:22+00:00       Biden        20697
# 2673   2673 2020-11-11 20:39:54+00:00       Trump       120068
# 2674   2674 2020-11-06 02:50:08+00:00       Trump       120009
# 2675   2675 2020-11-04 13:28:22+00:00       Trump       119839
#
#      Votes Remaining (est.)  Change      State  Leader Batch Breakdown  \
# 2670                    294    35.0  Wisconsin                    68.8
# 2671                    229   352.0  Wisconsin                    26.7
# 2672                    592     0.0  Wisconsin                     NaN
# 2673                     84   151.0    Wyoming                    69.5
# 2674                    237   180.0    Wyoming                    97.2
# 2675                    422     0.0    Wyoming                     NaN
#
#       Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 2670                     31.2                 82.6          3598.9
# 2671                     73.3                 73.3          4611.5
# 2672                      NaN                  NaN          1828.6
# 2673                     30.5                 15.4         74119.0
# 2674                      2.8                  2.8         26289.4
# 2675                      NaN                  NaN         14765.5
#
#       Margin_change_estimate     Type  Batch Votes Winner  Batch Votes Loser  \
# 2670                    24.0  updated                 5.5               29.5
# 2671                   164.0                         94.0              258.0
# 2672                     NaN                    1610140.0          1589354.0
# 2673                    59.0                        105.0               46.0
# 2674                   170.0                        175.0                5.0
# 2675                     NaN                          NaN                NaN
#
#       Accum. Votes Winner  Accum. Votes Loser
# 2670            1610328.5           1589869.5
# 2671            1610234.5           1589611.5
# 2672            1610140.0           1589354.0
# 2673             193559.0             73491.0
# 2674             193384.0             73486.0
# 2675                  NaN                 NaN

# %%
result_df.loc[2675, 'Accum. Votes Winner'] = (193384 - 175)
result_df.loc[2675, 'Accum. Votes Loser'] = (73486 - 5)
result_df.loc[2675, 'Batch Votes Winner'] = (193384 - 175)
result_df.loc[2675, 'Batch Votes Loser'] = (73486 - 5)

# %%
result_df[2670: 2676]
# Out:
#       index                 Timestamp In The Lead  Vote Margin  \
# 2670   2670 2020-11-04 18:30:33+00:00       Biden        20509
# 2671   2671 2020-11-04 17:57:21+00:00       Biden        20533
# 2672   2672 2020-11-04 13:28:22+00:00       Biden        20697
# 2673   2673 2020-11-11 20:39:54+00:00       Trump       120068
# 2674   2674 2020-11-06 02:50:08+00:00       Trump       120009
# 2675   2675 2020-11-04 13:28:22+00:00       Trump       119839
#
#      Votes Remaining (est.)  Change      State  Leader Batch Breakdown  \
# 2670                    294    35.0  Wisconsin                    68.8
# 2671                    229   352.0  Wisconsin                    26.7
# 2672                    592     0.0  Wisconsin                     NaN
# 2673                     84   151.0    Wyoming                    69.5
# 2674                    237   180.0    Wyoming                    97.2
# 2675                    422     0.0    Wyoming                     NaN
#
#       Trailer Batch Breakdown  Trailer Batch Trend  Trailer Hurdle  \
# 2670                     31.2                 82.6          3598.9
# 2671                     73.3                 73.3          4611.5
# 2672                      NaN                  NaN          1828.6
# 2673                     30.5                 15.4         74119.0
# 2674                      2.8                  2.8         26289.4
# 2675                      NaN                  NaN         14765.5
#
#       Margin_change_estimate     Type  Batch Votes Winner  Batch Votes Loser  \
# 2670                    24.0  updated                 5.5               29.5
# 2671                   164.0                         94.0              258.0
# 2672                     NaN                    1610140.0          1589354.0
# 2673                    59.0                        105.0               46.0
# 2674                   170.0                        175.0                5.0
# 2675                     NaN                     193209.0            73481.0
#
#       Accum. Votes Winner  Accum. Votes Loser
# 2670            1610328.5           1589869.5
# 2671            1610234.5           1589611.5
# 2672            1610140.0           1589354.0
# 2673             193559.0             73491.0
# 2674             193384.0             73486.0
# 2675             193209.0             73481.0

# %%
result_df.to_csv('./data/cleaned_records.csv', index=False)

# %%
time_end = pd.Timestamp.now()
print(time_end)
# Out:
# 2022-01-19 04:04:30.174822

# %%
print(f'Elapsed time: {time_end - time_start}')
# Out:
# Elapsed time: 0 days 00:00:23.489245

# %% [markdown]
# ## Analyze Trends

# %% [markdown]
# ### Metrics
# * Need table of each column and how many valid rows, invalid rows, and calculated rows
# * With data analysis -what is the difference between dropping all 'Unknown' and '0' values for the "Change" column and removal of all percentages outside 0 to 100.
# * Need to show the effect of calculating the Unknown columns versus what the effect would be by dropping it.
# * Need to show the residual of vote percents (vote_pred - vote_recorded) and vote margins.
# * Need to show outliers by plotting the change in margin versus the change in candidate votes - are there outliers - what did this look like before cleaning

# %%
# df = result_df

# %%
# df.columns

# %%
# max = df['Timestamp'].max()

# %%
# min = df['Timestamp'].min()
# min

# %%
# ax = df.groupby('State').plot(y='Accum. Votes Winner', x='Timestamp', figsize=(80, 10));
# ax.set_xlim(pd.Timestamp(min), pd.Timestamp(max))

# %%
# df.plot(y='Accum. Votes Winner', x='Timestamp')

# %% [markdown]
# ## Format Data for Database

# %% [markdown]
# Format of database
#   * batch # (use index - continuous across all states)
#   * datetime
#   * candidate
#   * votes for candidate
#   * state
#   * district (empty for now)
#   * type ( :: accepted, rejected, calculated)

# %%
batch_records = []
dict = {}
for i in range(len(result_df)):
    datetime = result_df.iloc[i,1]
    leader = result_df.iloc[i,2]
    leader_votes = result_df.iloc[i,13]
    state = result_df.iloc[i,6]
    district = ""
    type_desc = result_df.iloc[i,12]
    
    if (leader == 'Trump'):
        runner_up = 'Biden'
    else:
        runner_up = 'Trump'
    
    runner_up_votes = result_df.iloc[i,14]
    
    dict = {
        "datetime": datetime,
        "candidate": leader,
        "votes": leader_votes,
        "state": state,
        "dictrict": district,
        "type": type_desc
    }
    
    batch_records.append(dict)
    
    dict = {
        "datetime": datetime,
        "candidate": runner_up,
        "votes": runner_up_votes,
        "state": state,
        "dictrict": district,
        "type": type_desc
    }
    
    batch_records.append(dict)

# %%
df = pd.DataFrame(batch_records)
df
# Out:
#                       datetime candidate     votes    state dictrict type
# 0    2020-11-23 20:33:25+00:00     Trump    1095.0  Alabama
# 1    2020-11-23 20:33:25+00:00     Biden    1381.0  Alabama
# 2    2020-11-23 20:11:23+00:00     Trump    2983.0  Alabama
# 3    2020-11-23 20:11:23+00:00     Biden    2911.0  Alabama
# 4    2020-11-23 19:48:16+00:00     Trump    2933.0  Alabama
# ...                        ...       ...       ...      ...      ...  ...
# 5347 2020-11-11 20:39:54+00:00     Biden      46.0  Wyoming
# 5348 2020-11-06 02:50:08+00:00     Trump     175.0  Wyoming
# 5349 2020-11-06 02:50:08+00:00     Biden       5.0  Wyoming
# 5350 2020-11-04 13:28:22+00:00     Trump  193209.0  Wyoming
# 5351 2020-11-04 13:28:22+00:00     Biden   73481.0  Wyoming
#
# [5352 rows x 6 columns]

# %%
df.dtypes
# Out:
# datetime     datetime64[ns, UTC]
# candidate                 object
# votes                    float64
# state                     object
# dictrict                  object
# type                      object
# dtype: object

# %%
df.describe()
# Out:
#               votes
# count  5.352000e+03
# mean   2.892839e+04
# std    2.599932e+05
# min   -1.018950e+04
# 25%    5.600000e+01
# 50%    4.750000e+02
# 75%    2.876750e+03
# max    7.721336e+06

# %%
df['votes'].value_counts()
# Out:
# 1.0        103
# 2.0         85
# 4.0         65
# 5.0         65
# 3.0         63
#           ...
# 298.0        1
# 75598.0      1
# 435.0        1
# 7497.0       1
# 1570.0       1
# Name: votes, Length: 2803, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5352 entries, 0 to 5351
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   datetime   5352 non-null   datetime64[ns, UTC]
#  1   candidate  5352 non-null   object
#  2   votes      5352 non-null   float64
#  3   state      5352 non-null   object
#  4   dictrict   5352 non-null   object
#  5   type       5352 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), object(4)
# memory usage: 251.0+ KB

# %%
df[df['votes'].isna()]
# looks like 2 nan values out of 5352 records
# these are the first record for each state and the district of columbia that don't have a calculated candidate votes
# Out:
# Empty DataFrame
# Columns: [datetime, candidate, votes, state, dictrict, type]
# Index: []
